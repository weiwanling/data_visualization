# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline
plt.plot(5,5,'o')
plt.show()

# %%
plt.title('Normal distribution')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
# %matplotlib notebook
plt.plot(5,5,'o')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.title('Normal distribution')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(33.75, 0.5, 'y')

# %%
# %matplotlib inline
data_series=pd.Series(np.random.randn(50))
data_series.plot(kind='line')
plt.show()

# %%
data_series.plot(kind='hist')
plt.show()
